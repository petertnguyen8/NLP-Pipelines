# %% [markdown]
# # Pipeline Project

# %% [markdown]
# You will be using the provided data to create a machine learning model pipeline.
#
# You must handle the data appropriately in your pipeline to predict whether an
# item is recommended by a customer based on their review.
# Note the data includes numerical, categorical, and text data.
#
# You should ensure you properly train and evaluate your model.

# %% [markdown]
# ## The Data

# %% [markdown]
# The dataset has been anonymized and cleaned of missing values.
#
# There are 8 features for to use to predict whether a customer recommends or does
# not recommend a product.
# The `Recommended IND` column gives whether a customer recommends the product
# where `1` is recommended and a `0` is not recommended.
# This is your model's target/

# %% [markdown]
# The features can be summarized as the following:
#
# - **Clothing ID**: Integer Categorical variable that refers to the specific piece being reviewed.
# - **Age**: Positive Integer variable of the reviewers age.
# - **Title**: String variable for the title of the review.
# - **Review Text**: String variable for the review body.
# - **Positive Feedback Count**: Positive Integer documenting the number of other customers who found this review positive.
# - **Division Name**: Categorical name of the product high level division.
# - **Department Name**: Categorical name of the product department name.
# - **Class Name**: Categorical name of the product class name.
#
# The target:
# - **Recommended IND**: Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.

# %% [markdown]
# ## Load Data

# %% [markdown]
# > Let's quickly check out the data and plan how we will preprocess each column for our model to better understand.

# %%
import pandas as pd

# Load data
df = pd.read_csv(
    'data/reviews.csv',
)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18442 entries, 0 to 18441
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing ID              18442 non-null  int64
#  1   Age                      18442 non-null  int64
#  2   Title                    18442 non-null  object
#  3   Review Text              18442 non-null  object
#  4   Positive Feedback Count  18442 non-null  int64
#  5   Division Name            18442 non-null  object
#  6   Department Name          18442 non-null  object
#  7   Class Name               18442 non-null  object
#  8   Recommended IND          18442 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.3+ MB
#    Clothing ID  Age                    Title  \
# 0         1077   60  Some major design flaws
# 1         1049   50         My favorite buy!
# 2          847   47         Flattering shirt
# 3         1080   49  Not for the very petite
# 4          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Positive Feedback Count  \
# 0  I had such high hopes for this dress and reall...                        0
# 1  I love, love, love this jumpsuit. it's fun, fl...                        0
# 2  This shirt is very flattering to all due to th...                        6
# 3  I love tracy reese dresses, but this one is no...                        4
# 4  I aded this in my basket at hte last mintue to...                        1
#
#     Division Name Department Name Class Name  Recommended IND
# 0         General         Dresses    Dresses                0
# 1  General Petite         Bottoms      Pants                1
# 2         General            Tops    Blouses                1
# 3         General         Dresses    Dresses                0
# 4  General Petite            Tops      Knits                1

# %% [markdown]
# ## Preparing features (`X`) & target (`y`)

# %%
data = df

# separate features from labels
X = data.drop('Recommended IND', axis=1)
y = data['Recommended IND'].copy()

print('Labels:', y.unique())
print('Features:')
display(X.head())
# Out:
# Labels: [0 1]
# Features:
#    Clothing ID  Age                    Title  \
# 0         1077   60  Some major design flaws
# 1         1049   50         My favorite buy!
# 2          847   47         Flattering shirt
# 3         1080   49  Not for the very petite
# 4          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Positive Feedback Count  \
# 0  I had such high hopes for this dress and reall...                        0
# 1  I love, love, love this jumpsuit. it's fun, fl...                        0
# 2  This shirt is very flattering to all due to th...                        6
# 3  I love tracy reese dresses, but this one is no...                        4
# 4  I aded this in my basket at hte last mintue to...                        1
#
#     Division Name Department Name Class Name
# 0         General         Dresses    Dresses
# 1  General Petite         Bottoms      Pants
# 2         General            Tops    Blouses
# 3         General         Dresses    Dresses
# 4  General Petite            Tops      Knits

# %%
# Split data into train and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.1,
    shuffle=True,
    random_state=27,
)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Let's do create some Pipelines for our Column Transformer for our numerical and categorical data columns

# %%
X_train.select_dtypes('number').columns
# Out:
# Index(['Clothing ID', 'Age', 'Positive Feedback Count'], dtype='object')

# %%
# I will create an index for numeric features for my preprocessing pipeline
num_columns = X_train.select_dtypes('number').drop(['Age'], axis=1).columns
print('Numerical features:', num_columns)

# I will create an index for categorical features for my preprocessing pipeline
cat_columns = X_train.select_dtypes('object').drop(['Review Text'], axis=1).columns
print('Categorical Features:', cat_columns)

# I will create an index for the review text for my nlp preprocessing pipeline
review_column = X_train[['Review Text']].columns
print('Review Feature:', review_column)

# I will make a seperate pipeline for age b/c it is an ordinal category where order matters
age_column = X_train[['Age']].columns
print('Age Feature:', age_column)
# Out:
# Numerical features: Index(['Clothing ID', 'Positive Feedback Count'], dtype='object')
# Categorical Features: Index(['Title', 'Division Name', 'Department Name', 'Class Name'], dtype='object')
# Review Feature: Index(['Review Text'], dtype='object')
# Age Feature: Index(['Age'], dtype='object')

# %%
# Let's create our numerical preprocessing pipeline

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('minmax', MinMaxScaler())
])

num_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('minmax', MinMaxScaler())])

# %%
# Let's create our categorical preprocessing pipeline

from sklearn.preprocessing import OneHotEncoder

cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehotencoder', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

cat_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %%
# let's create a pipeline just for Age b/c we are not using onthotencoder with Age

from sklearn.preprocessing import OrdinalEncoder

age_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

age_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('ordinalencoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1))])

# %% [markdown]
# ### Let's tackle our review data and transform it into numerical form for our machine learning model

# %%
from sklearn.base import TransformerMixin, BaseEstimator

# Creating a custom transformer to count specified characters
class CountCharacter(BaseEstimator, TransformerMixin):
    def __init__(self, character:str):
        self.character = character
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        counts = []
        for text in X:
            count = text.count(self.character)
            counts.append([count])
        return counts

# %%
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import FunctionTransformer
import numpy as np

initial_text_preprocess = Pipeline([
    ('dimension_reshaper', FunctionTransformer(np.reshape, kw_args={'newshape':-1}))
])
count_char = FeatureUnion([
    ('count?', CountCharacter('?')),
    ('count!', CountCharacter('!'))
])

count_char
# Out:
# FeatureUnion(transformer_list=[('count?', CountCharacter(character='?')),
#                                ('count!', CountCharacter(character='!'))])

# %%
text_pipeline = Pipeline([
    ('reshaper', initial_text_preprocess),
    ('count', count_char)
])

text_pipeline
# Out:
# Pipeline(steps=[('reshaper',
#                  Pipeline(steps=[('dimension_reshaper',
#                                   FunctionTransformer(func=<function reshape at 0x7a53bc0dab30>,
#                                                       kw_args={'newshape': -1}))])),
#                 ('count',
#                  FeatureUnion(transformer_list=[('count?',
#                                                  CountCharacter(character='?')),
#                                                 ('count!',
#                                                  CountCharacter(character='!'))]))])

# %%
# Custom transformer using nlp lemmatizer
class SpacyLemmatizer(BaseEstimator, TransformerMixin):
    
    def __init__(self,nlp):
        self.nlp = nlp
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        lemmatized = []
        for doc in self.nlp.pipe(X):
            lemmas = []
            for token in doc:
                if not token.is_stop:
                    lemmas.append(token.lemma_)
            lemmatized.append(' '.join(lemmas))  
        return lemmatized

# %%
# Let's download spacy before we continue
! python -m spacy download en_core_web_sm

import spacy

nlp = spacy.load('en_core_web_sm')
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 58.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/venv/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: packaging>=20.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.9.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: setuptools in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.5.0)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: numpy>=1.19.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.5)
# Requirement already satisfied: language-data>=1.2 in /opt/venv/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: rich>=10.11.0 in /opt/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.8.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /opt/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/venv/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /opt/venv/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_pipeline = Pipeline([
    ('reshaper', initial_text_preprocess),
    ('lemmatizer', SpacyLemmatizer(nlp)),
    ('tfidf', TfidfVectorizer(stop_words = 'english'))
])

tfidf_pipeline
# Out:
# Pipeline(steps=[('reshaper',
#                  Pipeline(steps=[('dimension_reshaper',
#                                   FunctionTransformer(func=<function reshape at 0x7a53bc0dab30>,
#                                                       kw_args={'newshape': -1}))])),
#                 ('lemmatizer',
#                  SpacyLemmatizer(nlp=<spacy.lang.en.English object at 0x7a538b677b20>)),
#                 ('tfidf', TfidfVectorizer(stop_words='english'))])

# %% [markdown]
# ## Building Pipeline

# %% [markdown]
# > Now that we have all of our preprocessing pipelines let's put them all together with Column Transformers

# %%
from sklearn.compose import ColumnTransformer

feature_engineering = ColumnTransformer([
    ('num', num_pipeline, num_columns),
    ('cat', cat_pipeline, cat_columns),
    ('age', age_pipeline, age_column),
    ('char_counts', text_pipeline, review_column),
    ('tfidf', tfidf_pipeline, review_column)
])

feature_engineering
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('minmax', MinMaxScaler())]),
#                                  Index(['Clothing ID', 'Positive Feedback Count'], dtype='object')),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['Title', 'Divisio...
#                                  Index(['Review Text'], dtype='object')),
#                                 ('tfidf',
#                                  Pipeline(steps=[('reshaper',
#                                                   Pipeline(steps=[('dimension_reshaper',
#                                                                    FunctionTransformer(func=<function reshape at 0x7a53bc0dab30>,
#                                                                                        kw_args={'newshape': -1}))])),
#                                                  ('lemmatizer',
#                                                   SpacyLemmatizer(nlp=<spacy.lang.en.English object at 0x7a538b677b20>)),
#                                                  ('tfidf',
#                                                   TfidfVectorizer(stop_words='english'))]),
#                                  Index(['Review Text'], dtype='object'))])

# %%
from sklearn.ensemble import RandomForestClassifier

model_pipeline= Pipeline([
    ('feature_engineering', feature_engineering),
    ('model', RandomForestClassifier(random_state = 7))
])

model_pipeline
# Out:
# Pipeline(steps=[('feature_engineering',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmax',
#                                                                    MinMaxScaler())]),
#                                                   Index(['Clothing ID', 'Positive Feedback Count'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_o...
#                                                   Pipeline(steps=[('reshaper',
#                                                                    Pipeline(steps=[('dimension_reshaper',
#                                                                                     FunctionTransformer(func=<function reshape at 0x7a53bc0dab30>,
#                                                                                                         kw_args={'newshape': -1}))])),
#                                                                   ('lemmatizer',
#                                                                    SpacyLemmatizer(nlp=<spacy.lang.en.English object at 0x7a538b677b20>)),
#                                                                   ('tfidf',
#                                                                    TfidfVectorizer(stop_words='english'))]),
#                                                   Index(['Review Text'], dtype='object'))])),
#                 ('model', RandomForestClassifier(random_state=7))])

# %% [markdown]
# ## Training Pipeline

# %%
model_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('feature_engineering',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmax',
#                                                                    MinMaxScaler())]),
#                                                   Index(['Clothing ID', 'Positive Feedback Count'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_o...
#                                                   Pipeline(steps=[('reshaper',
#                                                                    Pipeline(steps=[('dimension_reshaper',
#                                                                                     FunctionTransformer(func=<function reshape at 0x7a53bc0dab30>,
#                                                                                                         kw_args={'newshape': -1}))])),
#                                                                   ('lemmatizer',
#                                                                    SpacyLemmatizer(nlp=<spacy.lang.en.English object at 0x7a538b677b20>)),
#                                                                   ('tfidf',
#                                                                    TfidfVectorizer(stop_words='english'))]),
#                                                   Index(['Review Text'], dtype='object'))])),
#                 ('model', RandomForestClassifier(random_state=7))])

# %%
from sklearn.metrics import accuracy_score

y_pred = model_pipeline.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('The accuracy score of our model without fine tuning is:', accuracy)
# Out:
# The accuracy score of our model without fine tuning is: 0.8439024390243902

# %% [markdown]
# ## Fine-Tuning Pipeline

# %% [markdown]
# > We will be using RandomizedSearchCV just to save some time, but in another setting we might want to be using GridSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'model__n_estimators': [75, 100, 125],  # Number of trees in the forest
    'model__max_depth': [None, 4],  # Maximum depth of the tree
    'model__min_samples_split': [2, 5],  # Minimum number of samples required to split an internal node
    'model__min_samples_leaf': [1, 2],  # Minimum number of samples required to be at a leaf node
}

random_search = RandomizedSearchCV(estimator=model_pipeline, param_distributions=param_grid,
                                   cv=3, scoring='accuracy', verbose=3, random_state=7)

random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100;, score=0.844 total time= 2.2min
# [CV 2/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100;, score=0.843 total time= 2.1min
# [CV 3/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100;, score=0.840 total time= 2.1min
# [CV 1/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=125;, score=0.843 total time= 2.3min
# [CV 2/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=125;, score=0.840 total time= 2.2min
# [CV 3/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=125;, score=0.837 total time= 2.2min
# [CV 1/3] END model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=125;, score=0.832 total time= 2.1min
# [CV 2/3] END model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=125;, score=0.832 total time= 2.1min
# [CV 3/3] END model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=125;, score=0.827 total time= 2.1min
# [CV 1/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100;, score=0.815 total time= 1.6min
# [CV 2/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100;, score=0.816 total time= 1.5min
# [CV 3/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100;, score=0.815 total time= 1.5min
# [CV 1/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=125;, score=0.842 total time= 2.3min
# [CV 2/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=125;, score=0.842 total time= 2.3min
# [CV 3/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=125;, score=0.840 total time= 2.2min
# [CV 1/3] END model__max_depth=4, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=75;, score=0.815 total time= 1.5min
# [CV 2/3] END model__max_depth=4, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=75;, score=0.816 total time= 1.5min
# [CV 3/3] END model__max_depth=4, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=75;, score=0.815 total time= 1.6min
# [CV 1/3] END model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=75;, score=0.832 total time= 1.9min
# [CV 2/3] END model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=75;, score=0.833 total time= 1.8min
# [CV 3/3] END model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=75;, score=0.829 total time= 1.8min
# [CV 1/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100;, score=0.815 total time= 1.5min
# [CV 2/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100;, score=0.816 total time= 1.5min
# [CV 3/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100;, score=0.815 total time= 1.6min
# [CV 1/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=75;, score=0.815 total time= 1.6min
# [CV 2/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=75;, score=0.816 total time= 1.5min
# [CV 3/3] END model__max_depth=4, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=75;, score=0.815 total time= 1.5min
# [CV 1/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=75;, score=0.843 total time= 2.0min
# [CV 2/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=75;, score=0.843 total time= 2.0min
# [CV 3/3] END model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=75;, score=0.840 total time= 2.0min
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('feature_engineering',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer()),
#                                                                                                ('minmax',
#                                                                                                 MinMaxScaler())]),
#                                                                                Index(['Clothing ID', 'Positive Feedback Count'], dtype='object')),
#                                                                               ('cat',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('onehotencoder',
#                                                                                                 OneHotEncode...
#                                                                                                 SpacyLemmatizer(nlp=<spacy.lang.en.English object at 0x7a538b677b20>)),
#                                                                                                ('tfidf',
#                                                                                                 TfidfVectorizer(stop_words='english'))]),
#                                                                                Index(['Review Text'], dtype='object'))])),
#                                              ('model',
#                                               RandomForestClassifier(random_state=7))]),
#                    param_distributions={'model__max_depth': [None, 4],
#                                         'model__min_samples_leaf': [1, 2],
#                                         'model__min_samples_split': [2, 5],
#                                         'model__n_estimators': [75, 100, 125]},
#                    random_state=7, scoring='accuracy', verbose=3)

# %%
print('this is our best parameters according to our RandomSearchCV:', random_search.best_params_)
# Out:
# this is our best parameters according to our RandomSearchCV: {'model__n_estimators': 100, 'model__min_samples_split': 2, 'model__min_samples_leaf': 1, 'model__max_depth': None}

# %%
best_model = random_search.best_estimator_

# %%
best_pred = best_model.predict(X_test)
best_model_accuracy = accuracy_score(y_test, best_pred)
print('This is our accuracy based on our best model:', best_model_accuracy)
# Out:
# This is our accuracy based on our best model: 0.8439024390243902
